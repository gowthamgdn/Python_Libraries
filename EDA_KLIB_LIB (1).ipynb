# %%
import klib
import pandas as pd
#pip install klib


df = pd.read_csv('/content/drive/MyDrive/EDA/titanic_train.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# klib.describe - functions for visualizing datasets
#- klib.cat_plot(df) # returns a visualization of the number and frequency of categorical features
#- klib.corr_mat(df) # returns a color-encoded correlation matrix
#- klib.corr_plot(df) # returns a color-encoded heatmap, ideal for correlations
#- klib.corr_interactive_plot(df, split="neg").show() # returns an interactive correlation plot using plotly
#- klib.dist_plot(df) # returns a distribution plot for every numeric feature
#- klib.missingval_plot(df) # returns a figure containing information about missing values

# klib.clean - functions for cleaning datasets
#- klib.data_cleaning(df) # performs datacleaning (drop duplicates & empty rows/cols, adjust dtypes,...)
#- klib.clean_column_names(df) # cleans and standardizes column names, also called inside data_cleaning()
#- klib.convert_datatypes(df) # converts existing to more efficient dtypes, also called inside data_cleaning()
#- klib.drop_missing(df) # drops missing values, also called in data_cleaning()
#- klib.mv_col_handling(df) # drops features with high ratio of missing vals based on informational content
#- klib.pool_duplicate_subsets(df) # pools subset of cols based on duplicates with min. loss of information

# %%
klib.cat_plot(df)
# Out:
# GridSpec(6, 5)

# %%
klib.corr_mat(df)
# Out:
# /usr/local/lib/python3.10/dist-packages/klib/describe.py:275: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   return corr.style.applymap(color_negative_red).format("{:.2f}", na_rep="-")
# <style type="text/css">
# #T_c5195_row0_col0, #T_c5195_row0_col3, #T_c5195_row0_col6, #T_c5195_row1_col1, #T_c5195_row1_col5, #T_c5195_row1_col6, #T_c5195_row2_col2, #T_c5195_row2_col4, #T_c5195_row2_col5, #T_c5195_row3_col0, #T_c5195_row3_col3, #T_c5195_row3_col6, #T_c5195_row4_col2, #T_c5195_row4_col4, #T_c5195_row4_col5, #T_c5195_row4_col6, #T_c5195_row5_col1, #T_c5195_row5_col2, #T_c5195_row5_col4, #T_c5195_row5_col5, #T_c5195_row5_col6, #T_c5195_row6_col0, #T_c5195_row6_col1, #T_c5195_row6_col3, #T_c5195_row6_col4, #T_c5195_row6_col5, #T_c5195_row6_col6 {
#   color: None;
# }
# #T_c5195_row0_col1, #T_c5195_row0_col2, #T_c5195_row0_col4, #T_c5195_row0_col5, #T_c5195_row1_col0, #T_c5195_row1_col2, #T_c5195_row1_col3, #T_c5195_row1_col4, #T_c5195_row2_col0, #T_c5195_row2_col1, #T_c5195_row2_col3, #T_c5195_row2_col6, #T_c5195_row3_col1, #T_c5195_row3_col2, #T_c5195_row3_col4, #T_c5195_row3_col5, #T_c5195_row4_col0, #T_c5195_row4_col1, #T_c5195_row4_col3, #T_c5195_row5_col0, #T_c5195_row5_col3, #T_c5195_row6_col2 {
#   color: #FF3344;
# }
# </style>
# <table id="T_c5195" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c5195_level0_col0" class="col_heading level0 col0" >PassengerId</th>
#       <th id="T_c5195_level0_col1" class="col_heading level0 col1" >Survived</th>
#       <th id="T_c5195_level0_col2" class="col_heading level0 col2" >Pclass</th>
#       <th id="T_c5195_level0_col3" class="col_heading level0 col3" >Age</th>
#       <th id="T_c5195_level0_col4" class="col_heading level0 col4" >SibSp</th>
#       <th id="T_c5195_level0_col5" class="col_heading level0 col5" >Parch</th>
#       <th id="T_c5195_level0_col6" class="col_heading level0 col6" >Fare</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5195_level0_row0" class="row_heading level0 row0" >PassengerId</th>
#       <td id="T_c5195_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_c5195_row0_col1" class="data row0 col1" >-0.01</td>
#       <td id="T_c5195_row0_col2" class="data row0 col2" >-0.04</td>
#       <td id="T_c5195_row0_col3" class="data row0 col3" >0.04</td>
#       <td id="T_c5195_row0_col4" class="data row0 col4" >-0.06</td>
#       <td id="T_c5195_row0_col5" class="data row0 col5" >-0.00</td>
#       <td id="T_c5195_row0_col6" class="data row0 col6" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_c5195_level0_row1" class="row_heading level0 row1" >Survived</th>
#       <td id="T_c5195_row1_col0" class="data row1 col0" >-0.01</td>
#       <td id="T_c5195_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_c5195_row1_col2" class="data row1 col2" >-0.34</td>
#       <td id="T_c5195_row1_col3" class="data row1 col3" >-0.08</td>
#       <td id="T_c5195_row1_col4" class="data row1 col4" >-0.04</td>
#       <td id="T_c5195_row1_col5" class="data row1 col5" >0.08</td>
#       <td id="T_c5195_row1_col6" class="data row1 col6" >0.26</td>
#     </tr>
#     <tr>
#       <th id="T_c5195_level0_row2" class="row_heading level0 row2" >Pclass</th>
#       <td id="T_c5195_row2_col0" class="data row2 col0" >-0.04</td>
#       <td id="T_c5195_row2_col1" class="data row2 col1" >-0.34</td>
#       <td id="T_c5195_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_c5195_row2_col3" class="data row2 col3" >-0.37</td>
#       <td id="T_c5195_row2_col4" class="data row2 col4" >0.08</td>
#       <td id="T_c5195_row2_col5" class="data row2 col5" >0.02</td>
#       <td id="T_c5195_row2_col6" class="data row2 col6" >-0.55</td>
#     </tr>
#     <tr>
#       <th id="T_c5195_level0_row3" class="row_heading level0 row3" >Age</th>
#       <td id="T_c5195_row3_col0" class="data row3 col0" >0.04</td>
#       <td id="T_c5195_row3_col1" class="data row3 col1" >-0.08</td>
#       <td id="T_c5195_row3_col2" class="data row3 col2" >-0.37</td>
#       <td id="T_c5195_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_c5195_row3_col4" class="data row3 col4" >-0.31</td>
#       <td id="T_c5195_row3_col5" class="data row3 col5" >-0.19</td>
#       <td id="T_c5195_row3_col6" class="data row3 col6" >0.10</td>
#     </tr>
#     <tr>
#       <th id="T_c5195_level0_row4" class="row_heading level0 row4" >SibSp</th>
#       <td id="T_c5195_row4_col0" class="data row4 col0" >-0.06</td>
#       <td id="T_c5195_row4_col1" class="data row4 col1" >-0.04</td>
#       <td id="T_c5195_row4_col2" class="data row4 col2" >0.08</td>
#       <td id="T_c5195_row4_col3" class="data row4 col3" >-0.31</td>
#       <td id="T_c5195_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_c5195_row4_col5" class="data row4 col5" >0.41</td>
#       <td id="T_c5195_row4_col6" class="data row4 col6" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_c5195_level0_row5" class="row_heading level0 row5" >Parch</th>
#       <td id="T_c5195_row5_col0" class="data row5 col0" >-0.00</td>
#       <td id="T_c5195_row5_col1" class="data row5 col1" >0.08</td>
#       <td id="T_c5195_row5_col2" class="data row5 col2" >0.02</td>
#       <td id="T_c5195_row5_col3" class="data row5 col3" >-0.19</td>
#       <td id="T_c5195_row5_col4" class="data row5 col4" >0.41</td>
#       <td id="T_c5195_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_c5195_row5_col6" class="data row5 col6" >0.22</td>
#     </tr>
#     <tr>
#       <th id="T_c5195_level0_row6" class="row_heading level0 row6" >Fare</th>
#       <td id="T_c5195_row6_col0" class="data row6 col0" >0.01</td>
#       <td id="T_c5195_row6_col1" class="data row6 col1" >0.26</td>
#       <td id="T_c5195_row6_col2" class="data row6 col2" >-0.55</td>
#       <td id="T_c5195_row6_col3" class="data row6 col3" >0.10</td>
#       <td id="T_c5195_row6_col4" class="data row6 col4" >0.16</td>
#       <td id="T_c5195_row6_col5" class="data row6 col5" >0.22</td>
#       <td id="T_c5195_row6_col6" class="data row6 col6" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
klib.corr_plot(df)
# Out:
# <Axes: title={'center': 'Feature-correlation (pearson)'}>

# %%
klib.corr_interactive_plot(df, split="neg").show()
# Out:
# Displaying negative correlations. Specify a negative "threshold" to limit the results further.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="df8dbd43-909d-4302-88b2-b84c37142d01" class="plotly-graph-div" style="height:1056px; width:1152px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df8dbd43-909d-4302-88b2-b84c37142d01")) {                    Plotly.newPlot(                        "df8dbd43-909d-4302-88b2-b84c37142d01",                        [{"colorscale":[[0.0,"rgb(84,48,5)"],[0.1,"rgb(140,81,10)"],[0.2,"rgb(191,129,45)"],[0.3,"rgb(223,194,125)"],[0.4,"rgb(246,232,195)"],[0.5,"rgb(245,245,245)"],[0.6,"rgb(199,234,229)"],[0.7,"rgb(128,205,193)"],[0.8,"rgb(53,151,143)"],[0.9,"rgb(1,102,94)"],[1.0,"rgb(0,60,48)"]],"hoverongaps":false,"text":[["","","","",-0.55,"",""],["","","",-0.19,"","",-0.0],["","","",-0.31,"",-0.04,-0.06],["","","","",-0.37,-0.08,""],["","","","","",-0.34,-0.04],["","","","","","",-0.01],["","","","","","",""]],"textfont":{"size":12},"texttemplate":"%{text}","x":["Fare","Parch","SibSp","Age","Pclass","Survived","PassengerId"],"xgap":1,"y":["Fare","Parch","SibSp","Age","Pclass","Survived","PassengerId"],"ygap":1,"z":[[null,null,null,null,-0.5494996199439076,null,null],[null,null,null,-0.18911926263203524,null,null,-0.0016520124027188364],[null,null,null,-0.30824675892365677,null,-0.03532249888573556,-0.0575268337844415],[null,null,null,null,-0.36922601531551735,-0.07722109457217759,null],[null,null,null,null,null,-0.3384810359610152,-0.03514399403038104],[null,null,null,null,null,null,-0.005006660767066518],[null,null,null,null,null,null,null]],"zmax":0.5,"zmin":-0.5,"type":"heatmap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333 ...

# %%
klib.dist_plot(df)
# Out:
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
klib.missingval_plot(df)
# Out:
# GridSpec(6, 6)

# %% [markdown]
# **Cleaning the dataset**

# %%
klib.data_cleaning(df)
# Out:
# Shape of cleaned data: (891, 12) - Remaining NAs: 866
#
#
# Dropped rows: 0
#      of which 0 duplicates. (Rows (first 150 shown): [])
#
# Dropped columns: 0
#      of which 0 single valued.     Columns: []
# Dropped missing values: 0
# Reduced memory by at least: 0.05 MB (-62.5%)
#      passenger_id  survived  pclass  \
# 0               1         0       3
# 1               2         1       1
# 2               3         1       3
# 3               4         1       1
# 4               5         0       3
# ..            ...       ...     ...
# 886           887         0       2
# 887           888         1       1
# 888           889         0       3
# 889           890         1       1
# 890           891         0       3
#
#                                                   name     sex   age  sib_sp  \
# 0                              Braund, Mr. Owen Harris    male  22.0       1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0       1
# 2                               Heikkinen, Miss. Laina  female  26.0       0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0       1
# 4                             Allen, Mr. William Henry    male  35.0       0
# ..                                                 ...     ...   ...     ...
# 886                              Montvila, Rev. Juozas    male  27.0       0
# 887                       Graham, Miss. Margaret Edith  female  19.0       0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN       1
# 889                              Behr, Mr. Karl Howell    male  26.0       0
# 890                                Dooley, Mr. Patrick    male  32.0       0
#
#      parch            ticket       fare cabin embarked
# 0        0         A/5 21171   7.250000  <NA>        S
# 1        0          PC 17599  71.283302   C85        C
# 2        0  STON/O2. 3101282   7.925000  <NA>        S
# 3        0            113803  53.099998  C123        S
# 4        0            373450   8.050000  <NA>        S
# ..     ...               ...        ...   ...      ...
# 886      0            211536  13.000000  <NA>        S
# 887      0            112053  30.000000   B42        S
# 888      2        W./C. 6607  23.450001  <NA>        S
# 889      0            111369  30.000000  C148        C
# 890      0            370376   7.750000  <NA>        Q
#
# [891 rows x 12 columns]

# %%
 klib.clean_column_names(df) # cleans and standardizes column names, also called inside data_cleaning()
# Out:
#      passenger_id  survived  pclass  \
# 0               1         0       3
# 1               2         1       1
# 2               3         1       3
# 3               4         1       1
# 4               5         0       3
# ..            ...       ...     ...
# 886           887         0       2
# 887           888         1       1
# 888           889         0       3
# 889           890         1       1
# 890           891         0       3
#
#                                                   name     sex   age  sib_sp  \
# 0                              Braund, Mr. Owen Harris    male  22.0       1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0       1
# 2                               Heikkinen, Miss. Laina  female  26.0       0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0       1
# 4                             Allen, Mr. William Henry    male  35.0       0
# ..                                                 ...     ...   ...     ...
# 886                              Montvila, Rev. Juozas    male  27.0       0
# 887                       Graham, Miss. Margaret Edith  female  19.0       0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN       1
# 889                              Behr, Mr. Karl Howell    male  26.0       0
# 890                                Dooley, Mr. Patrick    male  32.0       0
#
#      parch            ticket     fare cabin embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
klib.convert_datatypes(df) # converts existing to more efficient dtypes, also called inside data_cleaning()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket       Fare Cabin Embarked
# 0        0         A/5 21171   7.250000  <NA>        S
# 1        0          PC 17599  71.283302   C85        C
# 2        0  STON/O2. 3101282   7.925000  <NA>        S
# 3        0            113803  53.099998  C123        S
# 4        0            373450   8.050000  <NA>        S
# ..     ...               ...        ...   ...      ...
# 886      0            211536  13.000000  <NA>        S
# 887      0            112053  30.000000   B42        S
# 888      2        W./C. 6607  23.450001  <NA>        S
# 889      0            111369  30.000000  C148        C
# 890      0            370376   7.750000  <NA>        Q
#
# [891 rows x 12 columns]

# %%
klib.drop_missing(df) # drops missing values, also called in data_cleaning()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
klib.mv_col_handling(df) # drops features with high ratio of missing vals based on informational content
# Out:
# /usr/local/lib/python3.10/dist-packages/klib/clean.py:443: FutureWarning:
#
# DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#
# /usr/local/lib/python3.10/dist-packages/klib/clean.py:449: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# /usr/local/lib/python3.10/dist-packages/klib/clean.py:449: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked
# 0        0         A/5 21171   7.2500        S
# 1        0          PC 17599  71.2833        C
# 2        0  STON/O2. 3101282   7.9250        S
# 3        0            113803  53.1000        S
# 4        0            373450   8.0500        S
# ..     ...               ...      ...      ...
# 886      0            211536  13.0000        S
# 887      0            112053  30.0000        S
# 888      2        W./C. 6607  23.4500        S
# 889      0            111369  30.0000        C
# 890      0            370376   7.7500        Q
#
# [891 rows x 11 columns]

# %%
klib.pool_duplicate_subsets(df)
# Out:
#      PassengerId                                               Name   Age  \
# 0              1                            Braund, Mr. Owen Harris  22.0
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2              3                             Heikkinen, Miss. Laina  26.0
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4              5                           Allen, Mr. William Henry  35.0
# ..           ...                                                ...   ...
# 886          887                              Montvila, Rev. Juozas  27.0
# 887          888                       Graham, Miss. Margaret Edith  19.0
# 888          889           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889          890                              Behr, Mr. Karl Howell  26.0
# 890          891                                Dooley, Mr. Patrick  32.0
#
#                Ticket  pooled_vars
# 0           A/5 21171            0
# 1            PC 17599            1
# 2    STON/O2. 3101282            2
# 3              113803            3
# 4              373450            4
# ..                ...          ...
# 886            211536          134
# 887            112053          887
# 888        W./C. 6607          888
# 889            111369          889
# 890            370376          116
#
# [891 rows x 5 columns]
